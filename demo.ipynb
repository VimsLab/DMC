# %%
import os
import numpy as np
import meshplot as mp

# %% [markdown]
# #  Setup Display Properties

# %%
# %%html
# <style>
# .output_wrapper, .output {
#     height:auto !important;
#     width: auto; !important;
#     max-height:1500px;
#     max-width:1000px;
# }
# .output_scroll {
#     box-shadow:none !important;
#     webkit-box-shadow:none !important;
# }
# </style>
# Out:
# <style>
# .output_wrapper, .output {
#     height:auto !important;
#     width: auto; !important;
#     max-height:1500px;
#     max-width:1000px;
# }
# .output_scroll {
#     box-shadow:none !important;
#     webkit-box-shadow:none !important;
# }
# </style>

# %%
shading = {
    "flat":True, # Flat or smooth shading of triangles
    "scale":2.0,
    "wireframe":True, "wire_width": 0.1, "wire_color": "black", # Wireframe rendering
    "antialias": True, # Antialising, might not work on all GPUs
    "side": "DoubleSide", # FrontSide, BackSide or DoubleSide rendering of the triangles
    "colormap": "gist_gray", "normalize": [None, None], # Colormap and normalization for colors
    "background": "#ffffff", # Background color of the canvas
    "line_width": 1.0, "line_color": "black", # Line properties of overlay lines
    "bbox": False, # Enable plotting of bounding box
    "point_color": "red", "point_size": 0.01 # Point properties of overlay points
}

# %% [markdown]
# # Load Mesh

# %%
mesh = np.load('data/ModelNet40/airplane/train/airplane_0012.npz')

# %% [markdown]
# # Display Mesh

# %%
verts = mesh['verts']
faces = mesh['faces']
faces_feature = mesh['faces_feature']
centers, corners, normals = faces_feature[:3], faces_feature[3:12], faces_feature[12:]
faces_neighbor_1st_ring = mesh['faces_neighbor_1st_ring']
faces_neighbor_2nd_ring = mesh['faces_neighbor_2nd_ring']
faces_neighbor_3rd_ring = mesh['faces_neighbor_3rd_ring']


max_faces = faces.shape[0]
c = np.ones_like(faces)
for face_idx in range(380,381):
    c[face_idx] = [1, 0.5, 1]
    for face_neighbor_1st_ring in faces_neighbor_1st_ring[face_idx]:
        c[face_neighbor_1st_ring] = [1, 1, 0.5]
    for face_neighbor_2nd_ring in faces_neighbor_2nd_ring[face_idx]:
        c[face_neighbor_2nd_ring] = [0.5, 1, 1]
    for face_neighbor_3rd_ring in faces_neighbor_3rd_ring[face_idx]:
        c[face_neighbor_3rd_ring] = [1, 0.5, 0.1]


    plot = mp.plot(verts, faces, c=c, shading=shading, return_plot=True)
# Out:
# Renderer(camera=PerspectiveCamera(children=(DirectionalLight(color='white', intensity=0.6, position=(-0.114187…
